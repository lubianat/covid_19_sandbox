# %%
import pandas as pd

who_report_qid = "Q87779474"
who_report_date = "+2020-03-16T00:00:00Z/11"
who_table_with_qids = pd.read_csv("who_table_with_qids.csv")

for index, row in who_table_with_qids.iterrows():
        print(
      row['outbreak_qid'] +'|P1120|' + str(row['total_deaths']) + 
         "|S248|" + who_report_qid + "|S585|" + who_report_date + '\n' +
      row['outbreak_qid'] +'|P1603|' + str(row['total_cases']) + 
         "|S248|" + who_report_qid + "|S585|" + who_report_date + '\n' )
# Out:
# Q83872291|P1120|24.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
# Q83872291|P1603|814.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
#
# Q83873556|P1120|0.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
# Q83873556|P1603|553.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
#
# Q83873548|P1120|5.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
# Q83873548|P1603|298.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
#
# Q83873387|P1120|0.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
# Q83873387|P1603|243.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
#
# Q84055544|P1120|12.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
# Q84055544|P1603|140.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
#
# Q83888864|P1120|0.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
# Q83888864|P1603|12.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
#
# Q87250803|P1120|0.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
# Q87250803|P1603|6.0|S248|Q87779474|S585|+2020-03-16T00:00:00Z/11
#
# ...
